# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#How-large-is-our-dataset-when-we-restrict-to-women's-apparel?" data-toc-modified-id="How-large-is-our-dataset-when-we-restrict-to-women's-apparel?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>How large is our dataset when we restrict to women's apparel?</a></span></li></ul></div>

# %%
import os
import pandas as pd
import json
import numpy as np

# %%
DATA_DIR = "../data/external/fashion-dataset"
STYLES_PATH = os.path.join(DATA_DIR, "./styles.csv")

# %% [markdown]
# Read styles metadata:

# %%
# %%capture

df = pd.read_csv(STYLES_PATH, error_bad_lines=False)

# %%
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %% [markdown]
# # How large is our dataset when we restrict to women's apparel?

# %% [markdown]
# Restrict focus to women's apparel, and group by article type:

# %%
df_women = df.drop(['baseColour', 'season', 'year', 'usage', 'productDisplayName'], axis=1).groupby(
    ['gender', 'masterCategory', 'subCategory', 'articleType']).count().xs(('Women', 'Apparel'))

# %% [markdown]
# Breakdown of women's apparel counts in fashion-dataset:

# %%
df_women
# Out:
#                                                id
# subCategory              articleType
# Apparel Set              Kurta Sets            90
#                          Swimwear               2
# Bottomwear               Capris               129
#                          Churidar              23
#                          Jeans                228
#                          Jeggings              34
#                          Leggings             153
#                          Patiala               38
#                          Salwar                27
#                          Salwar and Dupatta     7
#                          Shorts                69
#                          Skirts               104
#                          Stockings             32
#                          Swimwear              10
#                          Tights                 8
#                          Track Pants           86
#                          Tracksuits             1
#                          Trousers              95
# Dress                    Dresses              388
#                          Jumpsuit              16
# Innerwear                Bra                  477
#                          Briefs               285
#                          Camisoles             39
#                          Innerwear Vests        1
#                          Shapewear              9
# Loungewear and Nightwear Baby Dolls            16
#                          Bath Robe             20
#                          Lounge Pants          26
#                          Lounge Shorts          9
#                          Lounge Tshirts         3
#                          Night suits           78
#                          Nightdress           189
#                          Robe                   4
#                          Shorts                 1
# Saree                    Sarees               427
# Topwear                  Blazers                2
#                          Dresses                2
#                          Dupatta              116
#                          Jackets               56
#                          Kurtas              1761
#                          Kurtis               232
#                          Lehenga Choli          2
#                          Shirts               294
#                          Shrug                  6
#                          Sweaters              88
#                          Sweatshirts           59
#                          Tops                1532
#                          Tshirts             1116
#                          Tunics               228
#                          Waistcoat              5

# %%
print("Women's apparel total image count: ", df_women.sum()['id'])
# Out:
# Women's apparel total image count:  8623

# %% [markdown]
# Save women's apparel ids:

# %%
women_ids = df.loc[(df['gender'] == 'Women') & (df['masterCategory'] == 'Apparel')]
women_ids.to_csv(
    '../data/processed/fashion-dataset/women_apparal_ids.csv',
    index=False, columns=['id'])

# %% [markdown]
# How are the json metadata files structured?

# %%
ids = [id for id in women_ids['id']]
with open('../data/external/fashion-dataset/styles/{}.json'.format(ids[0])) as f:
    example_md = json.load(f)
    print(json.dumps(example_md, indent=2))
# Out:
# {
#   "notification": {},
#   "meta": {
#     "code": 200,
#     "requestId": "92c5cd1a-219f-4c22-b5f3-60a929bf9a3a"
#   },
#   "data": {
#     "id": 26960,
#     "price": 699,
#     "discountedPrice": 699,
#     "styleType": "P",
#     "productTypeId": 320,
#     "articleNumber": "1JW06761",
#     "visualTag": "",
#     "productDisplayName": "Jealous 21 Women Purple Shirt",
#     "variantName": "Solid",
#     "myntraRating": 1,
#     "catalogAddDate": 1330675732,
#     "brandName": "Jealous 21",
#     "ageGroup": "Adults-Women",
#     "gender": "Women",
#     "baseColour": "Purple",
#     "colour1": "NA",
#     "colour2": "NA",
#     "fashionType": "Fashion",
#     "season": "Summer",
#     "year": "2012",
#     "usage": "Casual",
#     "vat": 5.5,
#     "displayCategories": "Casual Wear",
#     "weight": "0",
#     "navigationId": 1157,
#     "landingPageUrl": "Shirts/Jealous-21/Jealous-21-Women-Purple-Shirt/26960/buy",
#     "articleAttributes": {
#       "Fit": "Regular Fit",
#       "Pattern": "Solid",
#       "Body or Garment Size": "Garment Measurements in",
#       "Sleeve Length": "Short Sleeves",
#       "Fabric": "Cotton"
#     },
#     "crossLinks": [
#       {
#         "key": "More Shirts by Jealous 21",
#         "value": "shirts?f=brand:Jealous 21::gender:women"
#       },
#       {
#         "key": "More Purple Shirts",
#         "value": "shirts?f=colour:Purple::gender:women"
#       },
#       {
#         "key": "More Shirts",
#         "value": "shirts?f=gender:women"
#       }
#     ],
#     "brandUserProfile": {
#       "uidx": "2c21a0a6.e83e.4b77.995f.a1bc557da6b7p0smxLQw3u",
#       "bio": "Nothing Fits Like Jealous 21.",
#       "name": "Jealous 21",
#       "image": "http://assets.myntassets.com/assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg",
#       "publicProfileId": "Jealous21",
#       "imageJsonEntryMap": {
#         "0": "{\"id\":21304208,\"createdBy\":\"2c21a0a6.e83e.4b77.995f.a1bc557da6b7p0smxLQw3u\",\"createdOn\":1482138984000,\"lastModifiedOn\":1482138984000,\"version\":0,\"format\":\"JPEG\",\"isCompressed\":false,\"resolution\":\"680X680\",\"aspectRatio\":\"1:1\",\"viewtype\":\"front\",\"client_id\":4,\"client_description\":\"video_migration_script\",\"client_reference_id\":\"21304208\",\"imgs\":{\"S3\":{\"id\":36072770,\"relativePath\":\"assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\",\"size\":25855,\"domain\":\"http://myntra.myntassets.com/\",\"securedDomain\":\"https://myntrawebimages.s3.amazonaws.com/\",\"resolutionFormula\":\"assets/images/2016/12/19/11482138984191-25628-ji4cld_($width)_($height).jpg\",\"path\":\"http://myntra.myntassets.com/assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\",\"storedUploaderType\":\"S3\",\"servingUploaderType\":\"S3\"},\"CL\":{\"id\":36072769,\"relativePath\":\"assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\",\"size\":25855,\"domain\":\"http://assets.myntassets.com/\",\"securedDomain\":\"https://secureassets.myntassets.com/\",\"resolutionFormula\":\"h_($height),q_($qualityPercentage),w_($width)/v1/assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\",\"path\":\"http://assets.myntassets.com/assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\",\"storedUploaderType\":\"CL\",\"servingUploaderType\":\"CL\"}},\"path\":\"assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\",\"securedDomain\":\"https://secureassets.myntassets.com/\",\"domain\":\"http://assets.myntassets.com/\",\"storedUploaderType\":\"CL\",\"servingUploaderType\":\"CL\",\"resolutionFormula\":\"h_($height),q_($qualityPercentage),w_($width)/v1/assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg\"}",
#         "1": "{\"id\":21876102,\"createdBy\":\"2c21a0a6.e83e.4b77.995f.a1bc557da6b7p0smxLQw3u\",\"createdOn\":1482921081000,\"lastModifiedOn\":1482921081000,\"version\":0,\"format\":\"JPEG\",\"isCompressed\":false,\"resolution\":\"720X544\",\"aspectRatio\":\"45:34\",\"viewtype\":\"front\",\"client_id\":4,\"client_description\":\"video_migration_script\",\"client_reference_id\":\"21876102\",\"imgs\":{\"S3\":{\"id\":36977255,\"relativePath\":\"assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\",\"size\":77165,\"domain\":\"http://myntra.myntassets.com/\",\"securedDomain\":\"https://myntrawebimages.s3.amazonaws.com/\",\"resolutionFormula\":\"assets/images/2016/12/28/11482921081559-18911-xctl7j_($width)_($height).jpg\",\"path\":\"http://myntra.myntassets.com/assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\",\"storedUploaderType\":\"S3\",\"servingUploaderType\":\"S3\"},\"CL\":{\"id\":36977254,\"relativePath\":\"assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\",\"size\":77165,\"domain\":\"http://assets.myntassets.com/\",\"securedDomain\":\"https://secureassets.myntassets.com/\",\"resolutionFormula\":\"h_($height),q_($qualityPercentage),w_($width)/v1/assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\",\"path\":\"http://assets.myntassets.com/assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\",\"storedUploaderType\":\"CL\",\"servingUploaderType\":\"CL\"}},\"path\":\"assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\",\"securedDomain\":\"https://secureassets.myntassets.com/\",\"domain\":\"http://assets.myntassets.com/\",\"storedUploaderType\":\"CL\",\"servingUploaderType\":\"CL\",\"resolutionFormula\":\"h_($height),q_($qualityPercentage),w_($width)/v1/assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg\"}",
#         "2": "http://assets.myntassets.com/assets/images/2016/12/19/11482138984191-25628-ji4cld.jpg",
#         "3": "http://assets.myntassets.com/assets/images/2016/12/28/11482921081559-18911-xctl7j.jpg"
#       },
#       "tagsMap": "{\"roles\":[],\"labels\":[],\"myntraVerified\":true,\"invited\":true}"
#     },
#     "codEnabled": true,
#     "colours": {
#       "colors": {
#         "26957": {
#           "dre_landing_page_url": "Shirts/Jealous-21/Jealous-21-Women-Purple-Shirt/26957/buy",
#           "styleid": 26957,
#           "global_attr_colour1": "NA",
#           "global_attr_base_colour": "Purple",
#           "search_image": "http://assets.myntassets.com/v1/images/style/properties/68c39f47440cb294ec9049b94b23176d_images.jpg"
#         },
#         "26958": {
#           "dre_landing_page_url": "Shirts/Jealous-21/Jealous-21-Women-Teal-Shirt/26958/buy",
#           "styleid": 26958,
#           "global_attr_colour1": "NA",
#           "global_attr_base_colour": "Teal",
#           "search_image": "http://assets.myntassets.com/v1/images/style/properties/Jealous-21-Women-Teal-Shirt_33d3c1ebfd4326101c5d138dbef83c65_images.jpg"
#         },
#         "26959": {
#           "dre_landing_page_url": "Shirts/Jealous-21/Jealous-21-Women-Pink-Shirt/26959/buy",
#           "styleid": 26959,
#           "global_attr_colour1": "NA",
#           "global_attr_base_colour": "Pink",
#           "search_image": "http://assets.myntassets.com/v1/images/style/properties/Jealous-21-Women-Pink-Shirt_2be751c2df8558fb7682f836dd678492_images.jpg"
#         }
#       }
#     },
#     "styleImages": {
#       "default": {
#         "imageURL": "http://assets.myntassets.com/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#         "resolutions": {
#           "1080X1440Xmini": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "48X64": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "1080X1440": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "150X200": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "360X480": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "180X240": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "360X480Xmini": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "180X240Xmini": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "150X200Xmini": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "48X64Xmini": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "125X161": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "125X161Xmini": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg"
#         },
#         "imageType": "default"
#       },
#       "size_representation": "http://assets.myntassets.com/assets/images/sizechart/2016/12/14/11481690794651-shirt_women.png",
#       "search": {
#         "imageURL": "http://assets.myntassets.com/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#         "resolutions": {
#           "1080X1440Xmini": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "48X64": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "1080X1440": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "150X200": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "360X480": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "180X240": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "360X480Xmini": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "180X240Xmini": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "150X200Xmini": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "48X64Xmini": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg",
#           "125X161": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images.jpg",
#           "125X161Xmini": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/45ddbc6a15140556214e15923244755b_images_mini.jpg"
#         },
#         "imageType": "search"
#       },
#       "back": {
#         "imageURL": "http://assets.myntassets.com/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#         "resolutions": {
#           "1080X1440Xmini": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images_mini.jpg",
#           "48X64": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#           "1080X1440": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#           "150X200": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#           "360X480": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#           "180X240": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#           "360X480Xmini": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images_mini.jpg",
#           "180X240Xmini": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images_mini.jpg",
#           "150X200Xmini": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images_mini.jpg",
#           "48X64Xmini": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images_mini.jpg",
#           "125X161": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images.jpg",
#           "125X161Xmini": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/7e07053f992ea18e782cdc9b18cf6a75_images_mini.jpg"
#         },
#         "imageType": "back"
#       },
#       "front": {
#         "imageURL": "http://assets.myntassets.com/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#         "resolutions": {
#           "1080X1440Xmini": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images_mini.jpg",
#           "48X64": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#           "1080X1440": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#           "150X200": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#           "360X480": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#           "180X240": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#           "360X480Xmini": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images_mini.jpg",
#           "180X240Xmini": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images_mini.jpg",
#           "150X200Xmini": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images_mini.jpg",
#           "48X64Xmini": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images_mini.jpg",
#           "125X161": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images.jpg",
#           "125X161Xmini": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/29c3e949f60bccc771203c6c5799b385_images_mini.jpg"
#         },
#         "imageType": "front"
#       },
#       "right": {
#         "imageURL": "http://assets.myntassets.com/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#         "resolutions": {
#           "1080X1440Xmini": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images_mini.jpg",
#           "48X64": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#           "1080X1440": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#           "150X200": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#           "360X480": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#           "180X240": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#           "360X480Xmini": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images_mini.jpg",
#           "180X240Xmini": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images_mini.jpg",
#           "150X200Xmini": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images_mini.jpg",
#           "48X64Xmini": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images_mini.jpg",
#           "125X161": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images.jpg",
#           "125X161Xmini": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/a2a10373912f1f0287f2bb1efafb840f_images_mini.jpg"
#         },
#         "imageType": "right"
#       },
#       "top": {
#         "imageURL": "http://assets.myntassets.com/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#         "resolutions": {
#           "1080X1440Xmini": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images_mini.jpg",
#           "48X64": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#           "1080X1440": "http://assets.myntassets.com/h_1440,q_95,w_1080/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#           "150X200": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#           "360X480": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#           "180X240": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#           "360X480Xmini": "http://assets.myntassets.com/h_480,q_95,w_360/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images_mini.jpg",
#           "180X240Xmini": "http://assets.myntassets.com/h_240,q_95,w_180/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images_mini.jpg",
#           "150X200Xmini": "http://assets.myntassets.com/h_200,q_95,w_150/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images_mini.jpg",
#           "48X64Xmini": "http://assets.myntassets.com/h_64,q_95,w_48/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images_mini.jpg",
#           "125X161": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images.jpg",
#           "125X161Xmini": "http://assets.myntassets.com/h_161,q_95,w_125/v1/images/style/properties/78af56326269a8358e2126ce80ac3dff_images_mini.jpg"
#         },
#         "imageType": "top"
#       }
#     },
#     "lookGoodAlbum": {},
#     "style360Images": {},
#     "masterCategory": {
#       "id": 9,
#       "typeName": "Apparel",
#       "active": true,
#       "socialSharingEnabled": true,
#       "isReturnable": true,
#       "isExchangeable": true,
#       "pickupEnabled": true,
#       "isTryAndBuyEnabled": true
#     },
#     "subCategory": {
#       "id": 31,
#       "typeName": "Topwear",
#       "active": true,
#       "socialSharingEnabled": true,
#       "isReturnable": true,
#       "isExchangeable": true,
#       "pickupEnabled": true,
#       "isTryAndBuyEnabled": true
#     },
#     "articleType": {
#       "id": 85,
#       "typeName": "Shirts",
#       "active": true,
#       "socialSharingEnabled": true,
#       "isReturnable": true,
#       "isExchangeable": true,
#       "pickupEnabled": true,
#       "isTryAndBuyEnabled": true,
#       "isMyntsEnabled": true,
#       "serviceabilityDisclaimer": {
#         "title": "",
#         "desc": ""
#       }
#     },
#     "isEMIEnabled": true,
#     "otherFlags": [
#       {
#         "dataType": "BOOLEAN",
#         "name": "isFragile",
#         "value": "false"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "isTryAndBuyEnabled",
#         "value": "true"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "isHazmat",
#         "value": "false"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "isJewellery",
#         "value": "false"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "isReturnable",
#         "value": "true"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "isExchangeable",
#         "value": "true"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "active",
#         "value": "true"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "socialSharingEnabled",
#         "value": "true"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "pickupEnabled",
#         "value": "true"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "isLarge",
#         "value": "false"
#       },
#       {
#         "dataType": "BOOLEAN",
#         "name": "codEnabled",
#         "value": "true"
#       }
#     ],
#     "articleDisplayAttr": {
#       "id": 85,
#       "core": {
#         "order": "0",
#         "display": "2",
#         "pdtDetail": "1",
#         "pdtDeliveryOptions": "2",
#         "pdtSimilar": "2",
#         "pdtLike": "2"
#       },
#       "social": {
#         "order": "1",
#         "display": "2",
#         "userLikes": "1",
#         "styleNotes": "2",
#         "crossSell": "1"
#       },
#       "explore": {
#         "display": "2",
#         "crosslink": "1",
#         "similar": "1",
#         "order": "2"
#       }
#     },
#     "productDescriptors": {
#       "description": {
#         "descriptorType": "description",
#         "value": "<p><strong>Composition<br /></strong> Purple shirt made of 100% cotton, has a spread collar with a split neckline, short puff sleeves, a full buttoned placket and inverse pintucks at the midriff<br /> <br /><strong> Fit</strong><br /> Regular<br /> <br /><strong> Wash care<br /></strong> Wash dark colours separately in warm water (maximum 40 degrees)<br /> Use mild detergent<br /> Do not wring or bleach<br /> Flat dry in shade<br /> Do not iron on print<br /> <br /> jealous 21 stays in-vogue with this stylish piece that is sure to become a love-forever favourite in your casual wardrobe. Wear it with form fitting denims and a blazer, style with understated accessories and peep-toe shoes.<br /> <br /><strong> Model statistics<br /></strong> The product is a size M on a model of height 5'8\" and chest 33\"</p>"
#       }
#     },
#     "styleOptions": [
#       {
#         "id": 112937,
#         "name": "Size",
#         "value": "S",
#         "unifiedSize": "S",
#         "unifiedSizeValue": "S",
#         "allSize": "S,34",
#         "skuId": 120508,
#         "skuAvailabilityDetailMap": {},
#         "warehouseIdToItemCountMap": {},
#         "inventoryCount": 0,
#         "available": false,
#         "active": true
#       },
#       {
#         "id": 112936,
#         "name": "Size",
#         "value": "M",
#         "unifiedSize": "M",
#         "unifiedSizeValue": "M",
#         "allSize": "M,36",
#         "skuId": 120509,
#         "skuAvailabilityDetailMap": {},
#         "warehouseIdToItemCountMap": {},
#         "inventoryCount": 0,
#         "available": false,
#         "active": true
#       },
#       {
#         "id": 112935,
#         "name": "Size",
#         "value": "L",
#         "unifiedSize": "L",
#         "unifiedSizeValue": "L",
#         "allSize": "L,38",
#         "skuId": 120510,
#         "skuAvailabilityDetailMap": {},
#         "warehouseIdToItemCountMap": {},
#         "inventoryCount": 0,
#         "available": false,
#         "active": true
#       },
#       {
#         "id": 112934,
#         "name": "Size",
#         "value": "XL",
#         "unifiedSize": "XL",
#         "unifiedSizeValue": "XL",
#         "allSize": "XL,40",
#         "skuId": 120511,
#         "skuAvailabilityDetailMap": {},
#         "warehouseIdToItemCountMap": {},
#         "inventoryCount": 0,
#         "available": false,
#         "active": true
#       }
#     ]
#   }
# }

# %%
from PIL import Image

# %% [markdown]
# List all of the image dimensions in women's apparel data:

# %%
dims = set(Image.open('../data/external/fashion-dataset/images/{}.jpg'.format(id)).size for id in ids)
dims
# Out:
# {(360, 480),
#  (540, 720),
#  (683, 1024),
#  (1080, 1440),
#  (1200, 1600),
#  (1354, 2020),
#  (1800, 2399),
#  (1800, 2400),
#  (1806, 2700),
#  (2500, 3333),
#  (2652, 3536),
#  (2700, 2700),
#  (2711, 3615),
#  (2759, 3678),
#  (2774, 3698),
#  (2804, 3739)}

# %% [markdown]
# TODO: use PIL to resize images.
